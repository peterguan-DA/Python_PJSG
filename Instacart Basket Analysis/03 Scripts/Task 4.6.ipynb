# %% [markdown]
# # 01 Importing libraries

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02 Importing Data

# %%
# Importing the data
df_orders_products_combined = pd.read_pickle(r'/Users/peterguan/Instacart Basket Analysis/02 Data/Prepared Data/orders_products_combined.pkl')

# %%
# Creating a path for easier exporting
path = R'/Users/peterguan/Instacart Basket Analysis'

# %%
path
# Out:
# '/Users/peterguan/Instacart Basket Analysis'

# %%
# Checking the dimensions of the dataframe
df_orders_products_combined.shape
# Out:
# (32434489, 12)

# %%
# Importing the cleaned 'df_prods' dataframe
df_prods = pd.read_csv(r'/Users/peterguan/Instacart Basket Analysis/02 Data/Prepared Data/products_checked.csv', index_col = False)

# %%
# Checking the dimensions
df_prods.shape
# Out:
# (49672, 6)

# %%
# Checking the top 5 rows
df_orders_products_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   2                  8                     NaN       14084
# 2                   2                  8                     NaN       12427
# 3                   2                  8                     NaN       26088
# 4                   2                  8                     NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %%
# Dropping the '_merge' column from the datafrom because it is left over from the last dataframe
df_orders_products_combined = df_orders_products_combined.drop(columns = ['_merge'])

# %%
df_orders_products_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   2                  8                     NaN       14084
# 2                   2                  8                     NaN       12427
# 3                   2                  8                     NaN       26088
# 4                   2                  8                     NaN       26405
#
#    add_to_cart_order  reordered
# 0                  1          0
# 1                  2          0
# 2                  3          0
# ...

# %%
# Checking the top 5 rows
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
c

# %%
# Checking the top 5 rows to see if merge was successful
df_ords_prods_merge_left.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             0             0   2539329        1             1
# 2             0             0   2539329        1             1
# 3             0             0   2539329        1             1
# 4             0             0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   2                  8                     NaN       14084
# 2                   2                  8                     NaN       12427
# 3                   2                  8                     NaN       26088
# 4                   2                  8                     NaN       26405
#
#    add_to_cart_order  reordered  Unnamed: 0_y  \
# 0                  1          0         195.0
# ...

# %%
# Counting (sum) how many values in the '_merge' column
df_ords_prods_merge_left['_merge'].value_counts()
# Out:
# _merge
# both          32405122
# left_only        30214
# right_only           0
# Name: count, dtype: int64

# %%
# Merging the 2 dataframes with a INNER JOIN
df_ords_prods_merge_inner = df_orders_products_combined.merge(df_prods, on = 'product_id', indicator = 'inner_merge')

# %%
# Checking the first 5 rows
df_ords_prods_merge_inner.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             0             0   2539329        1             1
# 2             0             0   2539329        1             1
# 3             0             0   2539329        1             1
# 4             0             0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   2                  8                     NaN       14084
# 2                   2                  8                     NaN       12427
# 3                   2                  8                     NaN       26088
# 4                   2                  8                     NaN       26405
#
#    add_to_cart_order  reordered  Unnamed: 0_y  \
# 0                  1          0           195
# ...

# %% [markdown]
# # 03 Exporting the data

# %%
# Exporting data as a 'pkl' file
df_ords_prods_merge_inner.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge.pkl'))
